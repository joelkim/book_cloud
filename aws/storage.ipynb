# %% [markdown]
# # 저장장치

# %% [markdown]
# ## EBS

# %% [markdown]
# - 하나의 인스턴스에 붙일 수 있는 SSD 볼륨

# %% [markdown]
# ### input/output operations per second (IOPS)

# %% [markdown]
# ### 카테고리

# %% [markdown]
# - gp2
# - gp3
# - io1
# - io2

# %% [markdown]
# ## EFS (Elastic File System)

# %% [markdown]
# ## Object Storage
