# %% [markdown]
# # 서비스와 카테고리

# %% [markdown]
# - AWS 제품과 기능은 "서비스(service)"라는 단위로 구성
# - 서비스는 편의상 "카테고리(category)"라는 그룹으로 묶여 있음

# %% [markdown]
# - 2026-07-24 현재
# - 30여개 카테고리에서 300개 이상의 서비스 제공중
# - 중요 카테고리와 서비스
#   - 보안 및 인증 서비스 카테고리
#     - IAM(Identity and Access Management) 서비스
#   - 네트워킹 서비스 카테고리
#     - VPC(Virtual Private Cloud) 서비스
#   - 계산 서비스 카테고리
#     - EC2(Elastic Compute Cloud) 서비스
#   - 관리 서비스 카테고리
#     - Systems Manager 서비스
#   - 저장 서비스 카테고리
#     - S3(Simple Storage Service) 서비스
#     - EFS(Elastic File System) 서비스
#   - 데이터베이스 서비스 카테고리
#     - RDS(Relational Database Service) 서비스
# - 기타 카테고리
#   - Analytics(21)
#   - Application Integration(9)
#   - AWS Management Console(4)
#   - Blockchain(2)
#   - Business Applications(15)
#   - Cloud Financial Management(5)
#   - Compute HPC(1)
#   - Containers(6)
#   - Cryptography & PKI(7)
#   - Customer Enablement Services(6)
#   - Decision Guides(27)
#   - Developer Tools(38)
#   - End User Computing(6)
#   - Front-End Web & Mobile(9)
#   - Game Development(3)
#   - General Reference(8)
#   - Internet of Things (IoT)(11)
#   - Machine Learning(34)
#   - Marketplace(1)
#   - Media Services(10)
#   - Migration & Transfer(12)
#   - Partner Central(1)
#   - Quantum Computing(1)
#   - Satellite(1)
#   - Serverless(12)
