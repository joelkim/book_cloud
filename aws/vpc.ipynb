# %% [markdown]
# # vpc

# %% [markdown]
# # VPC

# %% [markdown]
# ## Virtual Private Cloud

# %% [markdown]
# ### 할당 가능 대역

# %% [markdown]
# - RFC1918 사설 IPv4 대역 사용 권장
#   - 172.16.0.0
#   - 192.168.0.0
#   - 10.0.0.0
# - 범위는 `/16`~`/28` 만 가능

# %% [markdown]
# ## 서브넷

# %% [markdown]
# - VPC는 하나 이상의 서브넷을 가져야 함
